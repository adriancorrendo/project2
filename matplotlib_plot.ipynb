# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
# %matplotlib inline
glob.os.chdir('C:/Users/correndo/Desktop/Coding/introcoding-spring-2019/Datasets/')

# %%
dirname = 'C:/Users/correndo/Desktop/Coding/introcoding-spring-2019/Datasets/'
filename = 'mauna_loa_co2.csv'

# %%
df = pd.read_csv(dirname + filename)

# %%
decimal_date = df.year + df.month/12 # to create a continous variable to plot
df['decimal_date'] = decimal_date
#decimal_date

# %%
plt.plot(df.decimal_date, df.co2_ppm)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(df.decimal_date[0:50], df.co2_ppm[0:50], '-or') # '--r' dashed, 'y' yellow, 'g' green
plt.show()

# %%
print(plt.rcParams.items) #all the paramteres to edit

# %%
plt.figure(figsize=(8,5))
plt.plot(df.decimal_date[0:50], df.co2_ppm[0:50], '-or')
plt.ylabel("Carbon dioxide (ppm)")
plt.xlabel("Year")

plt.rcParams['axes.grid'] = True
plt.rcParams['grid.color'] = 'b'
plt.rcParams['xtick.labelsize'] = 14.0
plt.rcParams['axes.spines.top'] = False

plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(df.decimal_date[0:50], df.co2_ppm[0:50], '-or')
plt.ylabel("Carbon dioxide (ppm)")
plt.xlabel("Year")

plt.rcParams['axes.grid'] = True
plt.rcParams['xtick.labelsize'] = 14.0
plt.rcParams['axes.spines.top'] = False

plt.show()

# %%
F50 = df.loc[0:49,] #Taking the first 50 values of the "df dataset"
#F50

# %%
mean = F50.co2_ppm.mean()
mean
#mean_line = mean
#F50['Mean'] = mean_line
# Out:
# C:\Users\correndo\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
plt.plot(F50.decimal_date, F50.co2_ppm)
plt.show()

# %%
plt.plot(F50.decimal_date[0:50], F50.co2_ppm[0:50], '-r')
plt.plot(F50.decimal_date[0:50], F50.co2_ppm[0:50], 's', color='g')
plt.legend({'Carbond dioxide line', 'Carbon dioxide marker'})

plt.ylabel("$CO2$ (ppm)")
plt.xlabel("Year")

plt.axhline(mean, linestyle = '--', color = 'k')

plt.rcParams['axes.grid'] = False
plt.rcParams['xtick.labelsize'] = 14.0
plt.rcParams['axes.spines.top'] = False

plt.show()

# %%
print(plt.rcParams.items)
# Out:
# <bound method Mapping.items of RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-7, 7],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
# ...
